# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
import jax
import jax.numpy as jnp
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import jaxkdtree

# %%
toto = jnp.array(randn(100,3))

# %%
jaxkdtree.kNN(toto)
# Out:
# Array([[ 3.41621816e-01,  2.20310733e-01,  1.01756263e+00],
#        [ 3.29711676e-01,  4.41242522e-03,  7.09288359e-01],
#        [ 1.24860418e+00,  2.56467968e-01,  4.44940060e-01],
#        [ 2.83160836e-01, -3.24099153e-01, -4.85608071e-01],
#        [-1.27089873e-01,  9.54368353e-01,  4.65932339e-02],
#        [ 1.79939806e+00, -9.93958592e-01,  4.83247429e-01],
#        [ 1.51905012e+00,  9.04812336e-01, -1.19027033e-01],
#        [-2.64394820e-01, -5.62882543e-01, -7.79841006e-01],
#        [-5.51069140e-01, -1.93699803e-02,  1.86286736e+00],
#        [-6.79728985e-01,  1.42112628e-01, -2.22694561e-01],
#        [-5.82254231e-01,  7.37544537e-01,  6.13597333e-01],
#        [ 1.10751677e+00, -8.89083147e-01, -7.41356611e-01],
#        [ 1.01557958e+00,  1.36971667e-01,  1.06583345e+00],
#        [ 1.16778147e+00,  1.96090639e+00, -2.53876746e-01],
#        [ 6.62728190e-01,  1.07462859e+00,  1.39940858e-01],
#        [-7.66038537e-01, -1.10275090e+00, -1.90049279e+00],
# ...
